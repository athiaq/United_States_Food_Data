# %% [markdown]
# Research Question: Which retail food or beverage sale was most popular by year (nationally)?
#
# My analysis allowed me to find out which product was the most popular in the US for each of the four years for which data was available. I was also able to discern which products were the least popular by year throught the lens of volume sales and dollar amount spent.
#
# For 2019 the most popular product by volume sales was in the category of beverages and the subcategory was "fruit drinks and non-carbonated sugary" with volume sales of 1.213325e+11 items sold. The most popular product in terms of dollar sales was in the category of alcohol and the subcategory of "Other" reaching the dollar amount of $1.558222e+10. On the other hand, I found that the product with the minimum volume sales for 2019 was category: commercially prepared items, subcategory: regular meat fresh/frozen with volume sales of 2,751,774. The product with the lowest dollar sales was category: vegetables, subcategory: dark green canned with $7,245,749.
#
# In 2020 again beverages with subcategory "fruit drinks and non-carbonated sugary" proved to be most popular for volume sales with 5.751054e+11 of product sold. When looking at most popular prouct by dollar amount sold, catergort: meats, eggs, and nuts with the subcategory of "regular meat fresh/frozen" taking the top spot with $7.327842e+10 sold. When considering which product that had the least volume sales, I found that category: commercially prepared items, with the subcategory of "regular meat fresh/frozen" with volume sales of 13,471,817. The product that saw the lowest sales in terms of dollars for 2020 was again in the category of vegetables, specifically the same subcategory we observed in 2019, "dark green canned" with $34,961,225.
#
# For 2021, again we see beverages of the "fruit drinks and non-carbonated sugary" variety with the most product volume sales at 5.955803e+11. Maximum dollar sales was with category: meats, eggs, and nuts, subcategory: regular meat fresh/frozen at $7.432715e+10. The product with the lowest volume sales was in category: commercially prepared items, subcategory: regular meat fresh/frozen (13,938,424). And again we saw dark canned green vegetables having the lowest dollar sales ($31,110,090).
#
# In 2022, "fruit drinks and non-carbonated suagry" beverages once again held the top spot for volume sales (4.882566e+11), while the most popular product by dollar sales was "regular meat fresh/frozen" in the "meats, eggs, and nuts" category ($6.164968e+10). The lowest volume sales for 2022 was category: commercially prepared items, subcategory: regular meat fresh/frozen (11,978,771). Lowest dollar sales again was vegetables	of the dark green canned variety ($28,463,015).
#
# Each of the four year's whose data was observed had the same product with the highest volume sales (category: beverages; subcategory:fruit drinks and non-carbonated sugary) and the same product with the lowest volume sales (category: commercially prepared items; subcategory: regular meat fresh/frozen). All four years also proved to have the same minimum dollar sales product (category: vegetables; subcategory:dark green canned). 2020, 2021 and 2022 shared the same product with the highest dollar sales (category: meats, eggs, and nuts, subcategory: regular meat fresh/frozen). Only 2019 had one outlier, the category of alcohol (subcategory: other) proving to have the hgihest dollar sales.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
#Read CSV
national_df = pd.read_csv('National_Data.csv')
state_df = pd.read_csv('State_Data.csv')

# %%
#First 5 in dataframe
national_df.head(5)
# Out:
#          Date   Category                             Subcategory  \
# 0  2019-10-06    Alcohol                                   Other
# 1  2019-10-06  All Foods                               All Foods
# 2  2019-10-06  Beverages                Carbonated non-alcoholic
# 3  2019-10-06  Beverages  Fruit drinks and non-carbonated sugary
# 4  2019-10-06  Beverages                                   Other
#
#            Dollars Dollars last year Dollars 3 years ago     Unit sales  \
# 0   $1,147,839,728    $1,103,676,117                 NaN    149,457,055
# 1  $13,037,155,405   $12,828,308,605                 NaN  4,472,865,668
# 2     $734,178,640      $730,908,985                 NaN    314,189,214
# 3     $727,030,527      $684,647,029                 NaN    309,406,835
# 4     $227,124,765      $228,596,996                 NaN     36,060,894
#
#   Unit sales last year Unit sales 3 years ago    Volume sales  ...  \
# 0          145,377,279                    NaN      34,109,047  ...
# ...

# %%
#Find unique values for "Category" field
national_df['Category'].unique()
# Out:
# array(['Alcohol', 'All Foods', 'Beverages', 'Commercially prepared items',
#        'Dairy', 'Fats and oils', 'Fruits', 'Grains',
#        'Meats, eggs, and nuts', 'Other', 'Sugar and sweeteners',
#        'Vegetables', nan], dtype=object)

# %%
# Count unique values
x = len(pd.unique(national_df['Category']))
print(x)
# Out:
# 13

# %%
# Find unique values for "Subcategory" field
national_df['Subcategory'].unique()
# Out:
# array(['Other', 'All Foods', 'Carbonated non-alcoholic',
#        'Fruit drinks and non-carbonated sugary', 'Water',
#        'Not sweet canned (soups, sauces, etc)',
#        'Not sweet frozen (pizzas, french fries, fish sticks and entrees)',
#        'Not sweet packaged/Meals and sides', 'Not sweet packaged/Snacks',
#        'Regular meat fresh/frozen',
#        'Sweet frozen (ice cream, frozen desserts)',
#        'Sweet mixes (pancake, muffin, and cake mixes)',
#        'Sweet packaged (cookies, candy bars, bars)',
#        'Sweet ready-to-eat (bakery items)', 'Cheese', 'Regular-fat milk',
#        'Yogurt and other', 'Oils', 'Solids', 'Fruit juice',
#        'Whole canned', 'Whole fresh/frozen', 'Flour and mixes',
#        'Frozen/ready to cook',
#        'Packaged (bread, rolls, pita, tortilla, rice, pasta, cereal)',
#        'Eggs', 'Fish fresh/frozen',
#        'Nuts and seeds processed/nut butters', 'Nuts and seeds raw',
# ...

# %%
# Count unique values for subcategory field
n = len(pd.unique(national_df['Subcategory']))
print(n)
# Out:
# 45

# %%
#Count of different dates (day/month/year entries)
national_df["Date"].unique()
num_diff_dates = len(pd.unique(national_df['Date']))
print(num_diff_dates)
# Out:
# 160

# %%
national_df['Share'].sum()
# Out:
# 31810.7

# %%
test_1 = national_df[national_df['Date'] == '2019-10-06']

# %%
test_1.head(5)
# Out:
#          Date   Category                             Subcategory  \
# 0  2019-10-06    Alcohol                                   Other
# 1  2019-10-06  All Foods                               All Foods
# 2  2019-10-06  Beverages                Carbonated non-alcoholic
# 3  2019-10-06  Beverages  Fruit drinks and non-carbonated sugary
# 4  2019-10-06  Beverages                                   Other
#
#            Dollars Dollars last year Dollars 3 years ago     Unit sales  \
# 0   $1,147,839,728    $1,103,676,117                 NaN    149,457,055
# 1  $13,037,155,405   $12,828,308,605                 NaN  4,472,865,668
# 2     $734,178,640      $730,908,985                 NaN    314,189,214
# 3     $727,030,527      $684,647,029                 NaN    309,406,835
# 4     $227,124,765      $228,596,996                 NaN     36,060,894
#
#   Unit sales last year Unit sales 3 years ago    Volume sales  ...  \
# 0          145,377,279                    NaN      34,109,047  ...
# ...

# %%
test_1['Dollars'] = test_1['Dollars'].str.replace(',', '')
test_1['Dollars'] = test_1['Dollars'].str.replace('$', '')
test_1['Dollars'] = test_1['Dollars'].astype(float)

test_1['Dollars last year'] = test_1['Dollars last year'].str.replace(',', '')
test_1['Dollars last year'] = test_1['Dollars last year'].str.replace('$', '')
test_1['Dollars last year'] = test_1['Dollars last year'].astype(float)
# Out:
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\3737474978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_1['Dollars'] = test_1['Dollars'].str.replace(',', '')
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\3737474978.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   test_1['Dollars'] = test_1['Dollars'].str.replace('$', '')
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\3737474978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
(test_1['Dollars'].sum())/2
# Out:
# 13037155403.0

# %%
#Remove "All Foods" from category field because it's redundant when looking for specific categories
cleaned_national_data = national_df[national_df['Category'] != 'All Foods']
cleaned_national_data.dropna(how='all',inplace=True)
cleaned_national_data['Dollars'] = cleaned_national_data['Dollars'].str.replace(',', '')
cleaned_national_data['Dollars'] = cleaned_national_data['Dollars'].str.replace('$', '')
cleaned_national_data['Dollars'] = cleaned_national_data['Dollars'].astype(float)

cleaned_national_data['Dollars last year'] = cleaned_national_data['Dollars last year'].str.replace(',', '')
cleaned_national_data['Dollars last year'] = cleaned_national_data['Dollars last year'].str.replace('$', '')
cleaned_national_data['Dollars last year'] = cleaned_national_data['Dollars last year'].astype(float)

cleaned_national_data
# Out:
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\2412777726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_national_data.dropna(how='all',inplace=True)
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\2412777726.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_national_data['Dollars'] = cleaned_national_data['Dollars'].str.replace(',', '')
# ...

# %%
cleaned_national_data['year'] = pd.DatetimeIndex(cleaned_national_data['Date']).year
# Out:
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\1540069738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_national_data['year'] = pd.DatetimeIndex(cleaned_national_data['Date']).year

# %%
cleaned_national_data['year']
# Out:
# 0       2019
# 2       2019
# 3       2019
# 4       2019
# 5       2019
#         ...
# 8581    2022
# 8582    2022
# 8583    2022
# 8584    2022
# 8585    2022
# Name: year, Length: 8427, dtype: int64

# %%
# Check that "All Foods" is also removed from subcategory field
cleaned_national_data['Subcategory'].unique()
# Out:
# array(['Other', 'Carbonated non-alcoholic',
#        'Fruit drinks and non-carbonated sugary', 'Water',
#        'Not sweet canned (soups, sauces, etc)',
#        'Not sweet frozen (pizzas, french fries, fish sticks and entrees)',
#        'Not sweet packaged/Meals and sides', 'Not sweet packaged/Snacks',
#        'Regular meat fresh/frozen',
#        'Sweet frozen (ice cream, frozen desserts)',
#        'Sweet mixes (pancake, muffin, and cake mixes)',
#        'Sweet packaged (cookies, candy bars, bars)',
#        'Sweet ready-to-eat (bakery items)', 'Cheese', 'Regular-fat milk',
#        'Yogurt and other', 'Oils', 'Solids', 'Fruit juice',
#        'Whole canned', 'Whole fresh/frozen', 'Flour and mixes',
#        'Frozen/ready to cook',
#        'Packaged (bread, rolls, pita, tortilla, rice, pasta, cereal)',
#        'Eggs', 'Fish fresh/frozen',
#        'Nuts and seeds processed/nut butters', 'Nuts and seeds raw',
#        'Poultry fresh/frozen', 'Regular meat canned', 'Raw',
# ...

# %%
cleaned_national_data['Volume sales'] = cleaned_national_data['Volume sales'].str.replace(',', '')
cleaned_national_data['Volume sales'] = cleaned_national_data['Volume sales'].astype(float)
# Out:
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\1588796813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_national_data['Volume sales'] = cleaned_national_data['Volume sales'].str.replace(',', '')
# C:\Users\gmass\AppData\Local\Temp\ipykernel_19332\1588796813.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_national_data['Volume sales'] = cleaned_national_data['Volume sales'].astype(float)

# %%
grouped_multiple = cleaned_national_data.groupby(['year', 'Category', 'Subcategory']).agg({'Volume sales':'sum', 'Dollars' : 'sum'})
grouped_multiple = grouped_multiple.reset_index()
grouped_multiple = grouped_multiple[grouped_multiple['year'] != 2019]
print(grouped_multiple)
# Out:
#      year    Category                             Subcategory  Volume sales  \
# 53   2020     Alcohol                                   Other  1.952816e+09
# 54   2020   Beverages                Carbonated non-alcoholic  1.255828e+11
# 55   2020   Beverages  Fruit drinks and non-carbonated sugary  5.751054e+11
# 56   2020   Beverages                                   Other  4.842616e+09
# 57   2020   Beverages                                   Water  1.027408e+10
# ..    ...         ...                                     ...           ...
# 207  2022  Vegetables         Other-mostly water fresh/frozen  8.332547e+09
# 208  2022  Vegetables             Other-nutrient-dense canned  9.667618e+08
# 209  2022  Vegetables       Other-nutrient-dense fresh/frozen  3.112278e+09
# 210  2022  Vegetables                          Starchy canned  1.060781e+09
# 211  2022  Vegetables                    Starchy fresh/frozen  4.088746e+09
#
#           Dollars
# 53   6.992269e+10
# ...

# %%
# Looking at largest volume sales for 2020 data
grouped_multiple[grouped_multiple['year'] == 2020].sort_values('Volume sales', ascending = False)
# Out:
#      year                     Category  \
# 55   2020                    Beverages
# 54   2020                    Beverages
# 74   2020                       Fruits
# 82   2020        Meats, eggs, and nuts
# 69   2020                        Dairy
# 76   2020                       Fruits
# 66   2020  Commercially prepared items
# 89   2020        Meats, eggs, and nuts
# 60   2020  Commercially prepared items
# 101  2020                   Vegetables
# 81   2020                       Grains
# 90   2020                        Other
# 57   2020                    Beverages
# 87   2020        Meats, eggs, and nuts
# 61   2020  Commercially prepared items
# 71   2020                        Dairy
# 59   2020  Commercially prepared items
# 58   2020  Commercially prepared items
# 105  2020                   Vegetables
# 68   2020                        Dairy
# 64   2020  Commercially prepared items
# 56   2020                    Beverages
# 67   2020  Commercially prepared items
# ...

# %%
grouped_2019 = grouped_multiple[grouped_multiple['year'] == 2019]
grouped_2019.head()
# Out:
#    year   Category                             Subcategory  Volume sales  \
# 0  2019    Alcohol                                   Other  4.339582e+08
# 1  2019  Beverages                Carbonated non-alcoholic  2.714631e+10
# 2  2019  Beverages  Fruit drinks and non-carbonated sugary  1.213325e+11
# 3  2019  Beverages                                   Other  1.041710e+09
# 4  2019  Beverages                                   Water  2.162898e+09
#
#         Dollars
# 0  1.558222e+10
# 1  9.252945e+09
# 2  8.705104e+09
# 3  3.096237e+09
# 4  4.041086e+09

# %%
#Find max volume sales for 2019
grouped_2019_vol_max = grouped_2019[grouped_2019['Volume sales'] == grouped_2019['Volume sales'].max()]
grouped_2019_vol_max
# Out:
#    year   Category                             Subcategory  Volume sales  \
# 2  2019  Beverages  Fruit drinks and non-carbonated sugary  1.213325e+11
#
#         Dollars
# 2  8.705104e+09

# %%
#Find min volume sales for 2019
grouped_2019_vol_min = grouped_2019[grouped_2019['Volume sales'] == grouped_2019['Volume sales'].min()]
grouped_2019_vol_min
# Out:
#     year                     Category                Subcategory  \
# 10  2019  Commercially prepared items  Regular meat fresh/frozen
#
#     Volume sales    Dollars
# 10     2751774.0  9550460.0

# %%
# Put max and min volume sales for 2019 in same table
grouped_2019_vol = grouped_2019[(grouped_2019['Volume sales'] == grouped_2019['Volume sales'].min()) | (grouped_2019['Volume sales'] == grouped_2019['Volume sales'].max())]
grouped_2019_vol
# Out:
#     year                     Category                             Subcategory  \
# 2   2019                    Beverages  Fruit drinks and non-carbonated sugary
# 10  2019  Commercially prepared items               Regular meat fresh/frozen
#
#     Volume sales       Dollars
# 2   1.213325e+11  8.705104e+09
# 10  2.751774e+06  9.550460e+06

# %%
#Find max dollar sales for 2019
grouped_2019_dollars_max = grouped_2019[grouped_2019['Dollars'] == grouped_2019['Dollars'].max()]
grouped_2019_dollars_max
# Out:
#    year Category Subcategory  Volume sales       Dollars
# 0  2019  Alcohol       Other   433958232.0  1.558222e+10

# %%
#Find min dollar sales for 2019
grouped_2019_dollars_min = grouped_2019[grouped_2019['Dollars'] == grouped_2019['Dollars'].min()]
grouped_2019_dollars_min
# Out:
#     year    Category        Subcategory  Volume sales    Dollars
# 39  2019  Vegetables  Dark green canned     5703599.0  7245749.0

# %%
# Put max and min dollar sales for 2019 in same table
grouped_2019_dollars = grouped_2019[(grouped_2019['Dollars'] == grouped_2019['Dollars'].min()) | (grouped_2019['Dollars'] == grouped_2019['Dollars'].max())]
grouped_2019_dollars
# Out:
#     year    Category        Subcategory  Volume sales       Dollars
# 0   2019     Alcohol              Other   433958232.0  1.558222e+10
# 39  2019  Vegetables  Dark green canned     5703599.0  7.245749e+06

# %%
combined_2019 = pd.concat([grouped_2019_dollars,grouped_2019_vol])

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
def human_format(num, pos):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.2f%s' % (num, ['', 'K', 'M', 'B', 'T', 'P'][magnitude])



formatter = FuncFormatter(human_format)

#fig, ax = plt.subplots()
#ax.yaxis.set_major_formatter(formatter)

# %%
# The maximums and minimums for volume sales and dollar sales for 2019 in one table
combined_2019
# Out:
#     year                     Category                             Subcategory  \
# 0   2019                      Alcohol                                   Other
# 39  2019                   Vegetables                       Dark green canned
# 2   2019                    Beverages  Fruit drinks and non-carbonated sugary
# 10  2019  Commercially prepared items               Regular meat fresh/frozen
#
#     Volume sales       Dollars
# 0   4.339582e+08  1.558222e+10
# 39  5.703599e+06  7.245749e+06
# 2   1.213325e+11  8.705104e+09
# 10  2.751774e+06  9.550460e+06

# %%
ax = combined_2019.plot.scatter(x='Volume sales', y='Dollars',label='Subcategory')
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)

# %%
grouped_2020 = grouped_multiple[grouped_multiple['year'] == 2020]
grouped_2020.head()
# Out:
#     year   Category                             Subcategory  Volume sales  \
# 53  2020    Alcohol                                   Other  1.952816e+09
# 54  2020  Beverages                Carbonated non-alcoholic  1.255828e+11
# 55  2020  Beverages  Fruit drinks and non-carbonated sugary  5.751054e+11
# 56  2020  Beverages                                   Other  4.842616e+09
# 57  2020  Beverages                                   Water  1.027408e+10
#
#          Dollars
# 53  6.992269e+10
# 54  4.059433e+10
# 55  3.987284e+10
# 56  1.289023e+10
# 57  1.918995e+10

# %%
df2 = grouped_2020.query('Dollars == Dollars.max()')
print(df2)
# Out:
#     year               Category                Subcategory  Volume sales  \
# 89  2020  Meats, eggs, and nuts  Regular meat fresh/frozen  1.569692e+10
#
#          Dollars
# 89  7.327842e+10

# %%
df22 = grouped_2020.query('Dollars == Dollars.min()')
print(df22)
# Out:
#     year    Category        Subcategory  Volume sales     Dollars
# 92  2020  Vegetables  Dark green canned    28562064.0  34961225.0

# %%
#Find max volume sales for 2020
grouped_2020_vol_max = grouped_2020[grouped_2020['Volume sales'] == grouped_2020['Volume sales'].max()]
grouped_2020_vol_max
# Out:
#     year   Category                             Subcategory  Volume sales  \
# 55  2020  Beverages  Fruit drinks and non-carbonated sugary  5.751054e+11
#
#          Dollars
# 55  3.987284e+10

# %%
#Find min volume sales for 2020
grouped_2020_vol_min = grouped_2020[grouped_2020['Volume sales'] == grouped_2020['Volume sales'].min()]
grouped_2020_vol_min
# Out:
#     year                     Category                Subcategory  \
# 63  2020  Commercially prepared items  Regular meat fresh/frozen
#
#     Volume sales     Dollars
# 63    13471817.0  47544721.0

# %%
#Find max dollar sales for 2020
grouped_2020_dollars_max = grouped_2020[grouped_2020['Dollars'] == grouped_2020['Dollars'].max()]
grouped_2020_dollars_max
# Out:
#     year               Category                Subcategory  Volume sales  \
# 89  2020  Meats, eggs, and nuts  Regular meat fresh/frozen  1.569692e+10
#
#          Dollars
# 89  7.327842e+10

# %%
#Find min dollar sales for 2020
grouped_2020_dollars_min = grouped_2020[grouped_2020['Dollars'] == grouped_2020['Dollars'].min()]
grouped_2020_dollars_min
# Out:
#     year    Category        Subcategory  Volume sales     Dollars
# 92  2020  Vegetables  Dark green canned    28562064.0  34961225.0

# %%
# Put max and min volume sales for 2020 in same table
grouped_2020_vol = grouped_2020[(grouped_2020['Volume sales'] == grouped_2020['Volume sales'].min()) | (grouped_2020['Volume sales'] == grouped_2020['Volume sales'].max())]
grouped_2020_vol
# Out:
#     year                     Category                             Subcategory  \
# 55  2020                    Beverages  Fruit drinks and non-carbonated sugary
# 63  2020  Commercially prepared items               Regular meat fresh/frozen
#
#     Volume sales       Dollars
# 55  5.751054e+11  3.987284e+10
# 63  1.347182e+07  4.754472e+07

# %%
# Put max and min dollar sales for 2020 in same table
grouped_2020_dollars = grouped_2020[(grouped_2020['Dollars'] == grouped_2020['Dollars'].min()) | (grouped_2020['Dollars'] == grouped_2020['Dollars'].max())]
grouped_2020_dollars
# Out:
#     year               Category                Subcategory  Volume sales  \
# 89  2020  Meats, eggs, and nuts  Regular meat fresh/frozen  1.569692e+10
# 92  2020             Vegetables          Dark green canned  2.856206e+07
#
#          Dollars
# 89  7.327842e+10
# 92  3.496122e+07

# %%
combined_2020 = pd.concat([grouped_2020_dollars,grouped_2020_vol])

# %%
# The maximums and minimums for volume sales and dollar sales for 2020 in one table
combined_2020
# Out:
#     year                     Category                             Subcategory  \
# 89  2020        Meats, eggs, and nuts               Regular meat fresh/frozen
# 92  2020                   Vegetables                       Dark green canned
# 55  2020                    Beverages  Fruit drinks and non-carbonated sugary
# 63  2020  Commercially prepared items               Regular meat fresh/frozen
#
#     Volume sales       Dollars
# 89  1.569692e+10  7.327842e+10
# 92  2.856206e+07  3.496122e+07
# 55  5.751054e+11  3.987284e+10
# 63  1.347182e+07  4.754472e+07

# %%
ax = combined_2020.plot.scatter(x='Volume sales', y='Dollars',label='Subcategory')
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)
# Out:
# c:\Users\gmass\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
grouped_2021 = grouped_multiple[grouped_multiple['year'] == 2021]
grouped_2021.head()
# Out:
#      year   Category                             Subcategory  Volume sales  \
# 106  2021    Alcohol                                   Other  1.856786e+09
# 107  2021  Beverages                Carbonated non-alcoholic  1.275927e+11
# 108  2021  Beverages  Fruit drinks and non-carbonated sugary  5.955803e+11
# 109  2021  Beverages                                   Other  4.561945e+09
# 110  2021  Beverages                                   Water  1.084999e+10
#
#           Dollars
# 106  6.916376e+10
# 107  4.395923e+10
# 108  4.455206e+10
# 109  1.272314e+10
# 110  2.149820e+10

# %%
#Find max volume sales for 2021
grouped_2021_vol_max = grouped_2021[grouped_2021['Volume sales'] == grouped_2021['Volume sales'].max()]
grouped_2021_vol_max
# Out:
#      year   Category                             Subcategory  Volume sales  \
# 108  2021  Beverages  Fruit drinks and non-carbonated sugary  5.955803e+11
#
#           Dollars
# 108  4.455206e+10

# %%
#Find min volume sales for 2021
grouped_2021_vol_min = grouped_2021[grouped_2021['Volume sales'] == grouped_2021['Volume sales'].min()]
grouped_2021_vol_min
# Out:
#      year                     Category                Subcategory  \
# 116  2021  Commercially prepared items  Regular meat fresh/frozen
#
#      Volume sales     Dollars
# 116    13938424.0  59198098.0

# %%
# Put max and min volume sales for 2021 in same table
grouped_2021_vol = grouped_2021[(grouped_2021['Volume sales'] == grouped_2021['Volume sales'].min()) | (grouped_2021['Volume sales'] == grouped_2021['Volume sales'].max())]
grouped_2021_vol
# Out:
#      year                     Category  \
# 108  2021                    Beverages
# 116  2021  Commercially prepared items
#
#                                 Subcategory  Volume sales       Dollars
# 108  Fruit drinks and non-carbonated sugary  5.955803e+11  4.455206e+10
# 116               Regular meat fresh/frozen  1.393842e+07  5.919810e+07

# %%
#Find max dollar sales for 2021
grouped_2021_dollars_max = grouped_2021[grouped_2021['Dollars'] == grouped_2021['Dollars'].max()]
grouped_2021_dollars_max
# Out:
#      year               Category                Subcategory  Volume sales  \
# 142  2021  Meats, eggs, and nuts  Regular meat fresh/frozen  1.465098e+10
#
#           Dollars
# 142  7.432715e+10

# %%
#Find min dollar sales for 2021
grouped_2021_dollars_min = grouped_2021[grouped_2021['Dollars'] == grouped_2021['Dollars'].min()]
grouped_2021_dollars_min
# Out:
#      year    Category        Subcategory  Volume sales     Dollars
# 145  2021  Vegetables  Dark green canned    24639906.0  31110090.0

# %%
# Put max and min dollar sales for 2021 in same table
grouped_2021_dollars = grouped_2021[(grouped_2021['Dollars'] == grouped_2021['Dollars'].min()) | (grouped_2021['Dollars'] == grouped_2021['Dollars'].max())]
grouped_2021_dollars
# Out:
#      year               Category                Subcategory  Volume sales  \
# 142  2021  Meats, eggs, and nuts  Regular meat fresh/frozen  1.465098e+10
# 145  2021             Vegetables          Dark green canned  2.463991e+07
#
#           Dollars
# 142  7.432715e+10
# 145  3.111009e+07

# %%
combined_2021 = pd.concat([grouped_2021_dollars,grouped_2021_vol])

# %%
# The maximums and minimums for volume sales and dollar sales for 2021 in one table
combined_2021
# Out:
#      year               Category                Subcategory  Volume sales  \
# 142  2021  Meats, eggs, and nuts  Regular meat fresh/frozen  1.465098e+10
# 145  2021             Vegetables          Dark green canned  2.463991e+07
# 142  2021  Meats, eggs, and nuts  Regular meat fresh/frozen  1.465098e+10
# 145  2021             Vegetables          Dark green canned  2.463991e+07
#
#           Dollars
# 142  7.432715e+10
# 145  3.111009e+07
# 142  7.432715e+10
# 145  3.111009e+07

# %%
ax = combined_2021.plot.scatter(x='Volume sales', y='Dollars',label='Subcategory')
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)
# Out:
# c:\Users\gmass\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
grouped_2022 = grouped_multiple[grouped_multiple['year'] == 2022]
grouped_2022.head()
# Out:
#      year   Category                             Subcategory  Volume sales  \
# 159  2022    Alcohol                                   Other  1.441952e+09
# 160  2022  Beverages                Carbonated non-alcoholic  9.942056e+10
# 161  2022  Beverages  Fruit drinks and non-carbonated sugary  4.882566e+11
# 162  2022  Beverages                                   Other  3.701239e+09
# 163  2022  Beverages                                   Water  9.016022e+09
#
#           Dollars
# 159  5.535191e+10
# 160  3.882004e+10
# 161  3.948504e+10
# 162  1.079222e+10
# 163  1.971969e+10

# %%
#Find max volume sales for 2022
grouped_2022_vol_max = grouped_2022[grouped_2022['Volume sales'] == grouped_2022['Volume sales'].max()]
grouped_2022_vol_max
# Out:
#      year   Category                             Subcategory  Volume sales  \
# 161  2022  Beverages  Fruit drinks and non-carbonated sugary  4.882566e+11
#
#           Dollars
# 161  3.948504e+10

# %%
#Find min volume sales for 2022
grouped_2022_vol_min = grouped_2022[grouped_2022['Volume sales'] == grouped_2022['Volume sales'].min()]
grouped_2022_vol_min
# Out:
#      year                     Category                Subcategory  \
# 169  2022  Commercially prepared items  Regular meat fresh/frozen
#
#      Volume sales     Dollars
# 169    11978771.0  47498218.0

# %%
# Put max and min volumesales for 2022 in same table
grouped_2022_vol = grouped_2022[(grouped_2022['Volume sales'] == grouped_2022['Volume sales'].min()) | (grouped_2022['Volume sales'] == grouped_2022['Volume sales'].max())]
grouped_2022_vol
# Out:
#      year                     Category  \
# 161  2022                    Beverages
# 169  2022  Commercially prepared items
#
#                                 Subcategory  Volume sales       Dollars
# 161  Fruit drinks and non-carbonated sugary  4.882566e+11  3.948504e+10
# 169               Regular meat fresh/frozen  1.197877e+07  4.749822e+07

# %%
#Find max dollar sales for 2022
grouped_2022_dollars_max = grouped_2022[grouped_2022['Dollars'] == grouped_2022['Dollars'].max()]
grouped_2022_dollars_max
# Out:
#      year               Category                Subcategory  Volume sales  \
# 195  2022  Meats, eggs, and nuts  Regular meat fresh/frozen  1.125574e+10
#
#           Dollars
# 195  6.164968e+10

# %%
#Find min dollar sales for 2022
grouped_2022_dollars_max = grouped_2022[grouped_2022['Dollars'] == grouped_2022['Dollars'].min()]
grouped_2022_dollars_max
# Out:
#      year    Category        Subcategory  Volume sales     Dollars
# 198  2022  Vegetables  Dark green canned    19029077.0  28463015.0

# %%
# Put max and min dollar sales for 2022 in same table
grouped_2022_dollars = grouped_2022[(grouped_2022['Dollars'] == grouped_2022['Dollars'].min()) | (grouped_2022['Dollars'] == grouped_2022['Dollars'].max())]
grouped_2022_dollars
# Out:
#      year               Category                Subcategory  Volume sales  \
# 195  2022  Meats, eggs, and nuts  Regular meat fresh/frozen  1.125574e+10
# 198  2022             Vegetables          Dark green canned  1.902908e+07
#
#           Dollars
# 195  6.164968e+10
# 198  2.846302e+07

# %%
combined_2022 = pd.concat([grouped_2022_dollars,grouped_2022_vol])

# %%
# The maximums and minimums for volume sales and dollar sales for 2022 in one table
combined_2022
# Out:
#      year                     Category  \
# 195  2022        Meats, eggs, and nuts
# 198  2022                   Vegetables
# 161  2022                    Beverages
# 169  2022  Commercially prepared items
#
#                                 Subcategory  Volume sales       Dollars
# 195               Regular meat fresh/frozen  1.125574e+10  6.164968e+10
# 198                       Dark green canned  1.902908e+07  2.846302e+07
# 161  Fruit drinks and non-carbonated sugary  4.882566e+11  3.948504e+10
# 169               Regular meat fresh/frozen  1.197877e+07  4.749822e+07

# %%
ax = combined_2022.plot.scatter(x='Volume sales', y='Dollars',label='Subcategory')
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)
# Out:
# c:\Users\gmass\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
meat_bev_data = grouped_multiple[((grouped_multiple['Subcategory'] == 'Regular meat fresh/frozen') | (grouped_multiple['Subcategory'] == 'Fruit drinks and non-carbonated sugary'))]
#meat_bev_data.pivot(index = 'year',columns = 'Category', values = 'Dollars')
meat_bev_data=meat_bev_data.drop('Category',axis=1)
meat_bev_data = meat_bev_data.reset_index(drop=True)
meat_bev_data_grouped = meat_bev_data.groupby(['year','Subcategory']).agg({'Dollars' : 'sum', 'Volume sales':'sum'})
meat_bev_data_grouped
# Out:
#                                                   Dollars  Volume sales
# year Subcategory
# 2020 Fruit drinks and non-carbonated sugary  3.987284e+10  5.751054e+11
#      Regular meat fresh/frozen               7.332596e+10  1.571039e+10
# 2021 Fruit drinks and non-carbonated sugary  4.455206e+10  5.955803e+11
#      Regular meat fresh/frozen               7.438635e+10  1.466492e+10
# 2022 Fruit drinks and non-carbonated sugary  3.948504e+10  4.882566e+11
#      Regular meat fresh/frozen               6.169717e+10  1.126772e+10

# %%
meat_group = meat_bev_data_grouped[meat_bev_data_grouped.index.get_level_values(1) == 'Regular meat fresh/frozen']
meat_group
# Out:
#                                      Dollars  Volume sales
# year Subcategory
# 2020 Regular meat fresh/frozen  7.332596e+10  1.571039e+10
# 2021 Regular meat fresh/frozen  7.438635e+10  1.466492e+10
# 2022 Regular meat fresh/frozen  6.169717e+10  1.126772e+10

# %%
meat_fig,meat_ax = plt.subplots(nrows=2,ncols=1)
meat_group.unstack(level=1).plot(kind='bar',rot=0,ax=meat_ax,subplots=True,legend=False)
meat_ax[0].yaxis.set_major_formatter(human_format)
meat_ax[1].yaxis.set_major_formatter(human_format)
plt.tight_layout()

# %%
bev_group = meat_bev_data_grouped[meat_bev_data_grouped.index.get_level_values(1) == 'Fruit drinks and non-carbonated sugary']
bev_group
# Out:
#                                                   Dollars  Volume sales
# year Subcategory
# 2020 Fruit drinks and non-carbonated sugary  3.987284e+10  5.751054e+11
# 2021 Fruit drinks and non-carbonated sugary  4.455206e+10  5.955803e+11
# 2022 Fruit drinks and non-carbonated sugary  3.948504e+10  4.882566e+11

# %%
bev_fig,bev_ax = plt.subplots(nrows=2,ncols=1)
bev_group.unstack(level=1).plot(kind='bar',rot=0,ax=bev_ax,subplots=True,legend=False)
bev_ax[0].yaxis.set_major_formatter(human_format)
bev_ax[1].yaxis.set_major_formatter(human_format)
plt.tight_layout()

# %%
grouped_scatter = grouped_multiple.copy()
grouped_scatter = grouped_scatter.drop('Category',axis=1)
grouped_scatter = grouped_multiple.reset_index(drop=True)
grouped_scatter = grouped_scatter.groupby(['year','Subcategory']).agg({'Dollars' : 'sum', 'Volume sales':'sum'})
grouped_scatter
# Out:
#                                              Dollars  Volume sales
# year Subcategory
# 2020 Carbonated non-alcoholic           4.059433e+10  1.255828e+11
#      Cheese                             2.576396e+10  5.256089e+09
#      Dark green canned                  3.496122e+07  2.856206e+07
#      Dark green fresh/frozen            1.160662e+10  4.007685e+09
#      Eggs                               6.815575e+09  3.976743e+10
# ...                                              ...           ...
# 2022 Sweet ready-to-eat (bakery items)  1.785722e+10  3.749084e+09
#      Water                              1.971969e+10  9.016022e+09
#      Whole canned                       3.605930e+09  1.438326e+09
#      Whole fresh/frozen                 3.253834e+10  1.887931e+10
#      Yogurt and other                   1.386527e+10  5.897841e+09
#
# [129 rows x 2 columns]

# %%
from scipy import stats

# %%
scat_fig,scat_ax = plt.subplots(ncols=3,nrows=1,figsize=(15,7))
holder_2020 = grouped_scatter[grouped_scatter.index.get_level_values(level=0) == 2020]
holder_2020 = holder_2020[(np.abs(stats.zscore(holder_2020)) < 3).all(axis=1)]
holder_2020.plot(kind='scatter',x='Dollars',y='Volume sales',rot=45,ax=scat_ax[0],subplots=True,legend=True)

holder_2021 = grouped_scatter[grouped_scatter.index.get_level_values(level=0) == 2021]
holder_2021 = holder_2021[(np.abs(stats.zscore(holder_2021)) < 3).all(axis=1)]
holder_2021.plot(kind='scatter',x='Dollars',y='Volume sales',rot=45,ax=scat_ax[1],subplots=True,legend=True)


holder_2022 = grouped_scatter[grouped_scatter.index.get_level_values(level=0) == 2022]
holder_2022 = holder_2022[(np.abs(stats.zscore(holder_2022)) < 3).all(axis=1)]
holder_2022.plot(kind='scatter',x='Dollars',y='Volume sales',rot=45,ax=scat_ax[2],subplots=True,legend=True)

plt.setp(scat_ax, ylim=scat_ax[0].get_ylim(),xlim=scat_ax[0].get_xlim())

scat_ax[0].yaxis.set_major_formatter(human_format)
scat_ax[0].xaxis.set_major_formatter(human_format)
scat_ax[0].title.set_text("2020")

scat_ax[1].yaxis.set_major_formatter(human_format)
scat_ax[1].xaxis.set_major_formatter(human_format)
scat_ax[1].title.set_text("2021")

scat_ax[2].yaxis.set_major_formatter(human_format)
scat_ax[2].xaxis.set_major_formatter(human_format)
scat_ax[2].title.set_text("2022")
plt.tight_layout()
# Out:
# c:\Users\gmass\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
scat_fig,scat_ax = plt.subplots()
grouped_scatter.plot(kind='scatter',x='Dollars',y='Volume sales',rot=0,ax=scat_ax,subplots=True,legend=True,c=grouped_scatter.index.get_level_values(level=0),colormap='Greens')
scat_ax.yaxis.set_major_formatter(human_format)
scat_ax.xaxis.set_major_formatter(human_format)
plt.tight_layout()
